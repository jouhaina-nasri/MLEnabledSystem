# %% [markdown]
# # Avoid using Excessive display of irrelevant outputs or graphs

# %% [markdown]
# - Excessive display of irrelevant outputs or graphs can make it harder to understand the code and its outputs.
# - To avoid this, limit the display of outputs and graphs to those that are relevant and necessary for the analysis, and consider using appropriate display functions like print() or display() to control the output display.

# %%
# Instead of this
import matplotlib.pyplot as plt
import numpy as np

# Displaying a large number of plots to visualize the evolution of each variable.
for i in range(10):
    x = np.random.rand(100)
    y = np.random.rand(100)
    plt.scatter(x, y)
    plt.show()

# %%
# Do this 

import matplotlib.pyplot as plt
import numpy as np

# %%
# Displaying a large number of plots to visualize the evolution of each variable.
x = np.random.rand(100, 10)
plt.plot(x)
plt.xlabel('Temps')
plt.ylabel('Valeur')
plt.show()
